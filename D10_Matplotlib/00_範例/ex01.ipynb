# %%
import matplotlib.pyplot as plt

squares = [0, 1, 4, 9, 16, 25, 36, 49, 64]
# 串列 squares 數據是 y 軸的值
plt.plot(squares)
plt.show()

# %%
# 產生 0, 1, ... 8 串列
x = [x for x in range(9)]
squares = [0, 1, 4, 9, 16, 25, 36, 49, 64]
plt.plot(x, squares)
plt.show()

# %% [markdown]
# ### 格線

# %%
squares = [0, 1, 4, 9, 16, 25, 36, 49, 64]
# 串列squares數據是y軸的值
plt.plot(squares)
plt.grid()
# x軸刻度0-8, y軸刻度0-70
plt.axis([0, 8, 0, 70])
plt.show()

# %% [markdown]
# ### 座標刻度

# %%
squares = [0, 1, 4, 9, 16, 25, 36, 49, 64]
# 串列squares數據是y軸的值
plt.plot(squares)
# x軸刻度0-8, y軸刻度0-70
plt.axis([0, 8, 0, 70])
plt.show()

# %% [markdown]
# ### 標題

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.font_manager import fontManager

# 請自行下載字體
fontManager.addfont('TaipeiSansTCBeta-Regular.ttf')
mpl.rc('font', family='Taipei Sans TC Beta')
squares = [0, 1, 4, 9, 16, 25, 36, 49, 64]
# 線條寬度是10
plt.plot(squares, lw=10)
plt.title('圖表標題', fontsize=24)
plt.xlabel('Value', fontsize=16)
plt.ylabel('Square')
plt.show()

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.font_manager import fontManager

fontManager.addfont('TaipeiSansTCBeta-Regular.ttf')
mpl.rc('font', family='Taipei Sans TC Beta')
# 兩個資料
data1 = [1, 4, 9, 16, 25, 36, 49, 64]
data2 = [1, 3, 6, 10, 15, 21, 28, 36]
seq = [1,2,3,4,5,6,7,8]
# 繪圖
plt.plot(seq, data1, seq, data2)
# 以下字型大小是使用預設
plt.title("兩組資料")
plt.xlabel("x軸值")
plt.ylabel("y軸值")
plt.show()

# %% [markdown]
# ### 多線樣式一

# %%
import matplotlib.pyplot as plt

data1 = [1, 2, 3, 4, 5, 6, 7, 8]
data2 = [1, 4, 9, 16, 25, 36, 49, 64]
data3 = [1, 3, 6, 10, 15, 21, 28, 36]
data4 = [1, 7, 15, 26, 40, 57, 77, 100]

seq = [1, 2, 3, 4, 5, 6, 7, 8]
plt.plot(
    seq,data1,'-*',
    seq,data2,'-o',
    seq,data3,'-^',
    seq,data4,'-s'
)
plt.title("標題", fontsize=24)
plt.xlabel("x-Value", fontsize=14)
plt.ylabel("y-Value", fontsize=14)
plt.show()

# %% [markdown]
# ### 多線樣式二

# %%
import matplotlib.pyplot as plt

data1 = [1, 2, 3, 4, 5, 6, 7, 8]
data2 = [1, 4, 9, 16, 25, 36, 49, 64]
data3 = [1, 3, 6, 10, 15, 21, 28, 36]
data4 = [1, 7, 15, 26, 40, 57, 77, 100]

seq = [1, 2, 3, 4, 5, 6, 7, 8]
plt.plot(
    seq,data1,'g--',
    seq,data2,'r-.',
    seq,data3,'y:',
    seq,data4,'k.'
)
plt.title("標題", fontsize=24)
plt.xlabel("x-Value", fontsize=14)
plt.ylabel("y-Value", fontsize=14)
plt.show()

# %%
import matplotlib.pyplot as plt

Benz = [3367, 4120, 5539]
BMW = [4000, 3590, 4423]
Lexus = [5200, 4930, 5350]
seq = [2021, 2022, 2023]
plt.xticks(seq)
plt.plot(
    seq, Benz, '-*',
    seq, BMW, '-o',
    seq, Lexus, '-^'
)
plt.title("Sales Report", fontsize=24)
plt.xlabel("Year", fontsize=14)
plt.ylabel("Number of Sales", fontsize=14)
plt.show()

# %% [markdown]
# ### Legend

# %%
import matplotlib.pyplot as plt

Benz = [3367, 4120, 5539]
BMW = [4000, 3590, 4423]
Lexus = [5200, 4930, 5350]
seq = [2021, 2022, 2023]

# 設定x軸刻度
plt.xticks(seq)
plt.plot(seq, Benz, '-*', label='Benz')
plt.plot(seq, BMW, '-o', label='BMW')
plt.plot(seq, Lexus, '-^', label='Lexus')
plt.legend(loc='best')
plt.title("Sales Report", fontsize=24)
plt.xlabel("Year", fontsize=14)
plt.ylabel("Number of Sales", fontsize=14)
plt.show()

# %% [markdown]
# ### 圖存檔

# %%
import matplotlib.pyplot as plt

Benz = [3367, 4120, 5539]
BMW = [4000, 3590, 4423]
Lexus = [5200, 4930, 5350]
seq = [2021, 2022, 2023]
plt.xticks(seq)
plt.plot(seq, Benz, '-*', label='Benz')
plt.plot(seq, BMW, '-o', label='BMW')
plt.plot(seq, Lexus, '-^', label='Lexus')
plt.legend(loc='best')
plt.title("Sales Report", fontsize=24)
plt.xlabel("Year", fontsize=14)
plt.ylabel("Number of Sales", fontsize=14)
plt.savefig('_sales.jpg')
plt.show()

# %% [markdown]
# ### 讀檔並顯示

# %%
import matplotlib.pyplot as plt
import matplotlib.image as img

fig = img.imread('_sales.jpg')
plt.imshow(fig)
plt.show()

# %% [markdown]
# ### 散點圖

# %%
import matplotlib.pyplot as plt

xpt = [1,2,3,4,5]
ypt = [1,4,9,16,25]
plt.scatter(xpt, ypt)
plt.show()
