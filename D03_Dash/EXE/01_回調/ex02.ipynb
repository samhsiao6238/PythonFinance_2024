# %% [markdown]
# 取得資料

# %%
import pandas as pd
import requests

url = "https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json"

# 發送請求並獲取數據
response = requests.get(url)

# 檢查請求是否成功
if response.status_code == 200:
    # 將資料解析為JSON
    data = response.json()
    # 轉換為DataFrame
    df = pd.DataFrame(data)
    # 列印前幾行數據
    print(df.head())
else:
    print("無法下載數據，狀態碼：", response.status_code)
# Out:
#          sno                     sna  tot  sbi sarea                 mday  \
# 0  500101001      YouBike2.0_捷運科技大樓站   28    2   大安區  2023-12-13 10:52:05
# 1  500101002  YouBike2.0_復興南路二段273號前   21    1   大安區  2023-12-13 10:52:05
# 2  500101003    YouBike2.0_國北教大實小東側門   16    0   大安區  2023-12-13 10:52:05
# 3  500101004       YouBike2.0_和平公園東側   11    0   大安區  2023-12-13 10:52:05
# 4  500101005    YouBike2.0_辛亥復興路口西北側   16    1   大安區  2023-12-13 10:52:05
#
#         lat        lng             ar     sareaen  \
# 0  25.02605  121.54360    復興南路二段235號前  Daan Dist.
# 1  25.02565  121.54357   復興南路二段273號西側  Daan Dist.
# 2  25.02429  121.54124    和平東路二段96巷7號  Daan Dist.
# 3  25.02351  121.54282  和平東路二段118巷33號  Daan Dist.
# 4  25.02153  121.54299     復興南路二段368號  Daan Dist.
#
#                                                snaen  \
# 0               YouBike2.0_MRT Technology Bldg. Sta.
# 1           YouBike2.0_No.273， Sec. 2， Fuxing S. Rd.
# 2  YouBike2.0_NTUE Experiment Elementary School (...
# 3                      YouBike2.0_Heping Park (East)
# 4  YouBike2.0_Xinhai Fuxing Rd. Intersection (Nor...
#
#                                     aren  bemp act        srcUpdateTime  \
# 0          No.235， Sec. 2， Fuxing S. Rd.    25   1  2023-12-13 10:52:40
# 1   No.273， Sec. 2， Fuxing S. Rd. (West)    20   1  2023-12-13 10:52:40
# 2    No. 7， Ln. 96， Sec. 2， Heping E. Rd    16   1  2023-12-13 10:52:40
# 3  No. 33， Ln. 118， Sec. 2， Heping E. Rd    11   1  2023-12-13 10:52:40
# 4         No. 368， Sec. 2， Fuxing S. Rd.    15   1  2023-12-13 10:52:40
#
#             updateTime             infoTime    infoDate
# 0  2023-12-13 10:52:52  2023-12-13 10:52:05  2023-12-13
# 1  2023-12-13 10:52:52  2023-12-13 10:52:05  2023-12-13
# 2  2023-12-13 10:52:52  2023-12-13 10:52:05  2023-12-13
# 3  2023-12-13 10:52:52  2023-12-13 10:52:05  2023-12-13
# 4  2023-12-13 10:52:52  2023-12-13 10:52:05  2023-12-13

# %%
column_mapping = {
    "sno": "站點編號",
    "sna": "站點名稱",
    "tot": "車位總數",
    "sbi": "可借車數",
    "sarea": "所在區域",
    "mday": "資料更新時間",
    "lat": "緯度",
    "lng": "經度",
    "ar": "地址",
    "sareaen": "區域英文名稱",
    "snaen": "站點英文名稱",
    "aren": "地址英文",
    "bemp": "空位數量",
    "act": "啟用狀態",
    "srcUpdateTime": "來源更新時間",
    "updateTime": "更新時間",
    "infoTime": "訊息時間",
    "infoDate": "訊息日期"
}

# %%
# 應用映射以更改欄位名稱
df.rename(columns=column_mapping, inplace=True)
df
# Out:
#            站點編號                      站點名稱  車位總數  可借車數    所在區域  \
# 0     500101001        YouBike2.0_捷運科技大樓站    28     2     大安區
# 1     500101002    YouBike2.0_復興南路二段273號前    21     1     大安區
# 2     500101003      YouBike2.0_國北教大實小東側門    16     0     大安區
# 3     500101004         YouBike2.0_和平公園東側    11     0     大安區
# 4     500101005      YouBike2.0_辛亥復興路口西北側    16     1     大安區
# ...         ...                       ...   ...   ...     ...
# 1321  500119087      YouBike2.0_臺大總圖書館西南側    30    12  臺大公館校區
# 1322  500119088        YouBike2.0_臺大黑森林西側    20    20  臺大公館校區
# 1323  500119089        YouBike2.0_臺大獸醫館南側    24    19  臺大公館校區
# 1324  500119090      YouBike2.0_臺大新體育館東南側    40    25  臺大公館校區
# 1325  500119091  YouBike2.0_臺大明達館北側(員工宿舍)    18     2  臺大公館校區
#
#                    資料更新時間        緯度         經度             地址      區域英文名稱  \
# 0     2023-12-13 10:52:05  25.02605  121.54360    復興南路二段235號前  Daan Dist.
# 1     2023-12-13 10:52:05  25.02565  121.54357   復興南路二段273號西側  Daan Dist.
# 2     2023-12-13 10:52:05  25.02429  121.54124    和平東路二段96巷7號  Daan Dist.
# 3     2023-12-13 10:52:05  25.02351  121.54282  和平東路二段118巷33號  Daan Dist.
# 4     2023-12-13 10:52:05  25.02153  121.54299     復興南路二段368號  Daan Dist.
# ...                   ...       ...        ...            ...         ...
# 1321  2023-12-13 10:52:17  25.01690  121.54031       臺大圖書館西南側    NTU Dist
# 1322  2023-12-13 10:52:17  25.01995  121.54347        臺大霖澤館南側    NTU Dist
# 1323  2023-12-13 10:52:17  25.01791  121.54242       臺大獸醫系館南側    NTU Dist
# 1324  2023-12-13 10:52:17  25.02112  121.53591        臺大體育館東側    NTU Dist
# 1325  2023-12-13 10:52:17  25.01816  121.54469       明達館北側前空地    NTU Dist
#
#                                                  站點英文名稱  \
# 0                  YouBike2.0_MRT Technology Bldg. Sta.
# 1              YouBike2.0_No.273， Sec. 2， Fuxing S. Rd.
# 2     YouBike2.0_NTUE Experiment Elementary School (...
# 3                         YouBike2.0_Heping Park (East)
# 4     YouBike2.0_Xinhai Fuxing Rd. Intersection (Nor...
# ...                                                 ...
# 1321             YouBike2.0_NTU Main Library(Southwest)
# 1322                  YouBike2.0_NTU Black Forest(West)
# 1323  YouBike2.0_NTU Dept. of Veterinary Medicine(So...
# 1324            YouBike2.0_NTU Sports Center(Southeast)
# 1325    YouBike2.0_NTU Ming - Da Hall (Staff Dormitory)
#
#                                          地址英文  空位數量 啟用狀態               來源更新時間  \
# 0               No.235， Sec. 2， Fuxing S. Rd.    25    1  2023-12-13 10:52:40
# 1        No.273， Sec. 2， Fuxing S. Rd. (West)    20    1  2023-12-13 10:52:40
# 2         No. 7， Ln. 96， Sec. 2， Heping E. Rd    16    1  2023-12-13 10:52:40
# 3       No. 33， Ln. 118， Sec. 2， Heping E. Rd    11    1  2023-12-13 10:52:40
# 4              No. 368， Sec. 2， Fuxing S. Rd.    15    1  2023-12-13 10:52:40
# ...                                       ...   ...  ...                  ...
# 1321              NTU Main Library(Southwest)    18    1  2023-12-13 10:52:40
# 1322             NTU Tsai Lecture Hall(South)     0    1  2023-12-13 10:52:40
# 1323  NTU Dept. of Veterinary Medicine(South)     1    1  2023-12-13 10:52:40
# 1324                  NTU Sports Center(East)    15    1  2023-12-13 10:52:40
# 1325               NTU Ming - Da Hall (North)    16    1  2023-12-13 10:52:40
#
#                      更新時間                 訊息時間        訊息日期
# 0     2023-12-13 10:52:52  2023-12-13 10:52:05  2023-12-13
# 1     2023-12-13 10:52:52  2023-12-13 10:52:05  2023-12-13
# 2     2023-12-13 10:52:52  2023-12-13 10:52:05  2023-12-13
# 3     2023-12-13 10:52:52  2023-12-13 10:52:05  2023-12-13
# 4     2023-12-13 10:52:52  2023-12-13 10:52:05  2023-12-13
# ...                   ...                  ...         ...
# 1321  2023-12-13 10:52:52  2023-12-13 10:52:17  2023-12-13
# 1322  2023-12-13 10:52:52  2023-12-13 10:52:17  2023-12-13
# 1323  2023-12-13 10:52:52  2023-12-13 10:52:17  2023-12-13
# 1324  2023-12-13 10:52:52  2023-12-13 10:52:17  2023-12-13
# 1325  2023-12-13 10:52:52  2023-12-13 10:52:17  2023-12-13
#
# [1326 rows x 18 columns]

# %%
# 假設 df 是先前處理過的 DataFrame
# 選擇所需的列
selected_columns = ["站點名稱", "車位總數", "可借車數", "所在區域"]

# 使用 selected_columns 選擇 DataFrame 的子集
selected_df = df[selected_columns]
# 顯示選擇列的前幾行數據
selected_df.head()
# Out:
#                      站點名稱  車位總數  可借車數 所在區域
# 0      YouBike2.0_捷運科技大樓站    28     2  大安區
# 1  YouBike2.0_復興南路二段273號前    21     1  大安區
# 2    YouBike2.0_國北教大實小東側門    16     0  大安區
# 3       YouBike2.0_和平公園東側    11     0  大安區
# 4    YouBike2.0_辛亥復興路口西北側    16     1  大安區

# %%
import dash
from dash import dcc, html, Input, Output
import plotly.express as px
import pandas as pd

# %%
# 建立 Dash 應用
app = dash.Dash(__name__)

# 定義佈局
app.layout = html.Div(
    [
        dcc.Dropdown(
            id="area-dropdown",
            options=[{"label": area, "value": area} for area in selected_df["所在區域"].unique()],
            value=selected_df["所在區域"].unique()[0],  # 預設值
        ),
        dcc.Graph(id="youbike-graph"),
    ]
)

# 定義callback來更新圖表
@app.callback(Output("youbike-graph", "figure"), Input("area-dropdown", "value"))
def update_graph(selected_area):
    # 根據選取的區域過濾數據
    filtered_df = selected_df[selected_df["所在區域"] == selected_area]

    # 產生圖表
    fig = px.bar(filtered_df, x="站點名稱", y=["車位總數", "可借車數"], barmode="group", title="YouBike站點數據")

    return fig

# 運行應用
if __name__ == "__main__":
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# 在目前儲存格或上一個儲存格中執行程式碼時，Kernel 已損毀。請檢閱儲存格中的程式碼，找出失敗的可能原因。如需詳細資訊，請按一下<a href='https://aka.ms/vscodeJupyterKernelCrash'>這裡</a>。檢視 Jupyter <a href='command:jupyter.viewOutput'>記錄</a>，以取得進一步的詳細資料。
