# %% [markdown]
# 彌補 yfinance 台股資料的不齊全

# %%
pip install FinMind

# %%
from FinMind.data import DataLoader

stock_no = '0050'
dl = DataLoader()
stock_data = dl.taiwan_stock_daily(stock_id=stock_no, start_date='2000-01-01')
stock_data.head()
# Out:
# /Users/samhsiao/Documents/PythonVenv/envDash/lib/python3.9/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# 2023-12-11 11:17:45.402 | INFO     | FinMind.data.finmind_api:get_data:123 - download TaiwanStockPrice, data_id: 0050
#          date stock_id  Trading_Volume  Trading_money   open    max    min  \
# 0  2003-06-30     0050         9930000      367884760  37.10  37.40  36.92
# 1  2003-07-01     0050        14290000      536078350  37.09  38.10  37.09
# 2  2003-07-02     0050        16232000      625636880  38.17  38.82  38.10
# 3  2003-07-03     0050        16839000      661217150  40.60  40.60  38.81
# 4  2003-07-04     0050        12491000      487753800  39.10  39.26  38.75
#
#    close  spread  Trading_turnover
# 0  37.08    0.12              2047
# 1  38.05    0.97              2223
# 2  38.69    0.64              1906
# 3  39.00    0.31              2230
# 4  39.26    0.26              1514

# %% [markdown]
# 上櫃股票 6533

# %%
from FinMind.data import DataLoader

stock_no = '6533'
dl = DataLoader()
stock_data = dl.taiwan_stock_daily(stock_id=stock_no, start_date='2000-01-01')
stock_data.head()
# Out:
# 2023-12-11 11:21:49.268 | INFO     | FinMind.data.finmind_api:get_data:123 - download TaiwanStockPrice, data_id: 6533
#          date stock_id  Trading_Volume  Trading_money   open    max    min  \
# 0  2017-03-14     6533         5889591      873611618  135.0  199.0  131.0
# 1  2017-03-15     6533         4132828      717279932  180.0  187.0  165.0
# 2  2017-03-16     6533         4399176      796947544  171.0  198.0  165.0
# 3  2017-03-17     6533         2926610      561723812  194.0  200.5  186.0
# 4  2017-03-20     6533         2010101      372890382  192.0  192.0  181.0
#
#    close  spread  Trading_turnover
# 0  189.5     0.0              4332
# 1  170.0   -19.5              3406
# 2  195.0    25.0              3685
# 3  192.0    -3.0              2535
# 4  183.0    -9.0              1731

# %% [markdown]
# FinMind 整合 ffn

# %% [markdown]
# ffn 的 index 是日期，但是 FinMind 的 index 是流水號，date 是其中一個欄位而且是 string 格式，所以我們要將 FinMind 的 index 改成日期格式的 date

# %% [markdown]
# 先確認有資料

# %%
stock_data
# Out:
#            stock_id  Trading_Volume  Trading_money   open    max    min  \
# date
# 2017-03-14     6533         5889591      873611618  135.0  199.0  131.0
# 2017-03-15     6533         4132828      717279932  180.0  187.0  165.0
# 2017-03-16     6533         4399176      796947544  171.0  198.0  165.0
# 2017-03-17     6533         2926610      561723812  194.0  200.5  186.0
# 2017-03-20     6533         2010101      372890382  192.0  192.0  181.0
# ...             ...             ...            ...    ...    ...    ...
# 2023-12-04     6533         2019938      954422769  479.5  479.5  467.0
# 2023-12-05     6533         1333463      615238979  465.0  467.0  457.0
# 2023-12-06     6533         2295286     1086617273  463.0  478.5  462.0
# 2023-12-07     6533         1284162      598150112  470.5  473.5  462.5
# 2023-12-08     6533         1494154      697001005  470.0  474.0  462.0
#
#             close  spread  Trading_turnover
# date
# 2017-03-14  189.5     0.0              4332
# 2017-03-15  170.0   -19.5              3406
# 2017-03-16  195.0    25.0              3685
# 2017-03-17  192.0    -3.0              2535
# 2017-03-20  183.0    -9.0              1731
# ...           ...     ...               ...
# 2023-12-04  467.0   -14.5              3299
# 2023-12-05  458.0    -9.0              2223
# 2023-12-06  476.0    18.0              2858
# 2023-12-07  462.5   -13.5              2188
# 2023-12-08  464.0     1.5              1891
#
# [1651 rows x 9 columns]

# %% [markdown]
# 以下這樣會報錯，因為在 Pandas 中，一旦某個列被設定為索引，它就不再被視為普通的欄位。 這表示如果您嘗試使用 set_index 方法將 date 欄位設為索引，將會導致 KeyError，因為 date 已不再是一個可識別的資料列，而是索引。

# %%
stock_data.set_index("date", inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/vm/_zft15050r7cfh47y6v5z4k40000gn/T/ipykernel_31479/3481618448.py in ?()
# ----> 1 stock_data.set_index("date" , inplace=True)
#
# ~/Documents/PythonVenv/envDash/lib/python3.9/site-packages/pandas/core/frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    5866                     if not found:
#    5867                         missing.append(col)
#    5868
#    5869         if missing:
# -> 5870             raise KeyError(f"None of {missing} are in the columns")
#    5871
#    5872         if inplace:
#    5873             frame = self
#
# KeyError: "None of ['date'] are in the columns"

# %% [markdown]
# 轉回索引

# %%
stock_data.reset_index(inplace=True)
stock_data
# Out:
#       index        date stock_id  Trading_Volume  Trading_money   open    max  \
# 0         0  2017-03-14     6533         5889591      873611618  135.0  199.0
# 1         1  2017-03-15     6533         4132828      717279932  180.0  187.0
# 2         2  2017-03-16     6533         4399176      796947544  171.0  198.0
# 3         3  2017-03-17     6533         2926610      561723812  194.0  200.5
# 4         4  2017-03-20     6533         2010101      372890382  192.0  192.0
# ...     ...         ...      ...             ...            ...    ...    ...
# 1646   1646  2023-12-04     6533         2019938      954422769  479.5  479.5
# 1647   1647  2023-12-05     6533         1333463      615238979  465.0  467.0
# 1648   1648  2023-12-06     6533         2295286     1086617273  463.0  478.5
# 1649   1649  2023-12-07     6533         1284162      598150112  470.5  473.5
# 1650   1650  2023-12-08     6533         1494154      697001005  470.0  474.0
#
#         min  close  spread  Trading_turnover
# 0     131.0  189.5     0.0              4332
# 1     165.0  170.0   -19.5              3406
# 2     165.0  195.0    25.0              3685
# 3     186.0  192.0    -3.0              2535
# 4     181.0  183.0    -9.0              1731
# ...     ...    ...     ...               ...
# 1646  467.0  467.0   -14.5              3299
# 1647  457.0  458.0    -9.0              2223
# 1648  462.0  476.0    18.0              2858
# 1649  462.5  462.5   -13.5              2188
# 1650  462.0  464.0     1.5              1891
#
# [1651 rows x 11 columns]

# %%
import pandas as pd
stock_data = stock_data.set_index(pd.DatetimeIndex(pd.to_datetime(stock_data.index)))
stock_data
# Out:
#                                index        date stock_id  Trading_Volume  \
# 1970-01-01 00:00:00.000000000      0  2017-03-14     6533         5889591
# 1970-01-01 00:00:00.000000001      1  2017-03-15     6533         4132828
# 1970-01-01 00:00:00.000000002      2  2017-03-16     6533         4399176
# 1970-01-01 00:00:00.000000003      3  2017-03-17     6533         2926610
# 1970-01-01 00:00:00.000000004      4  2017-03-20     6533         2010101
# ...                              ...         ...      ...             ...
# 1970-01-01 00:00:00.000001646   1646  2023-12-04     6533         2019938
# 1970-01-01 00:00:00.000001647   1647  2023-12-05     6533         1333463
# 1970-01-01 00:00:00.000001648   1648  2023-12-06     6533         2295286
# 1970-01-01 00:00:00.000001649   1649  2023-12-07     6533         1284162
# 1970-01-01 00:00:00.000001650   1650  2023-12-08     6533         1494154
#
#                                Trading_money   open    max    min  close  \
# 1970-01-01 00:00:00.000000000      873611618  135.0  199.0  131.0  189.5
# 1970-01-01 00:00:00.000000001      717279932  180.0  187.0  165.0  170.0
# 1970-01-01 00:00:00.000000002      796947544  171.0  198.0  165.0  195.0
# 1970-01-01 00:00:00.000000003      561723812  194.0  200.5  186.0  192.0
# 1970-01-01 00:00:00.000000004      372890382  192.0  192.0  181.0  183.0
# ...                                      ...    ...    ...    ...    ...
# 1970-01-01 00:00:00.000001646      954422769  479.5  479.5  467.0  467.0
# 1970-01-01 00:00:00.000001647      615238979  465.0  467.0  457.0  458.0
# 1970-01-01 00:00:00.000001648     1086617273  463.0  478.5  462.0  476.0
# 1970-01-01 00:00:00.000001649      598150112  470.5  473.5  462.5  462.5
# 1970-01-01 00:00:00.000001650      697001005  470.0  474.0  462.0  464.0
#
#                                spread  Trading_turnover
# 1970-01-01 00:00:00.000000000     0.0              4332
# 1970-01-01 00:00:00.000000001   -19.5              3406
# 1970-01-01 00:00:00.000000002    25.0              3685
# 1970-01-01 00:00:00.000000003    -3.0              2535
# 1970-01-01 00:00:00.000000004    -9.0              1731
# ...                               ...               ...
# 1970-01-01 00:00:00.000001646   -14.5              3299
# 1970-01-01 00:00:00.000001647    -9.0              2223
# 1970-01-01 00:00:00.000001648    18.0              2858
# 1970-01-01 00:00:00.000001649   -13.5              2188
# 1970-01-01 00:00:00.000001650     1.5              1891
#
# [1651 rows x 11 columns]

# %%
stats = stock_data["close"].describe()
print(stats)
# Out:
# count    1651.000000
# mean      265.577710
# std       168.468866
# min        60.000000
# 25%       122.000000
# 50%       156.000000
# 75%       426.000000
# max       627.000000
# Name: close, dtype: float64
