# %% [markdown]
# 集成於 yfinance，使用相同資料

# %%
pip install ffn

# %% [markdown]
# 要捉 SPY 2021年以後的資料

# %%
import ffn
# ffn 取得 股價
prices = ffn.get('spy', start='2021-01-01')
prices[0: 10]
# Out:
# /Users/samhsiao/Documents/PythonVenv/envDash/lib/python3.9/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# [*********************100%%**********************]  1 of 1 completed
#                    spy
# Date
# 2021-01-04  354.197418
# 2021-01-05  356.636841
# 2021-01-06  358.769073
# 2021-01-07  364.099487
# 2021-01-08  366.173981
# 2021-01-11  363.705688
# 2021-01-12  363.782501
# 2021-01-13  364.762146
# 2021-01-14  363.484711
# 2021-01-15  360.834015

# %% [markdown]
# 若出現錯誤訊息 TypeError: string indices must be integers

# %%
import yfinance
yfinance.pdr_override()

# %% [markdown]
# rebase ⇒ 將初始價格改為 100，可以比較兩個以上的股價漲跌變化

# %%
prices = ffn.get('spy, tlt', start='2021-01-01')
# rebase 股價繪圖
# %matplotlib inline
prices.rebase().plot()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# <Axes: xlabel='Date'>

# %% [markdown]
# to_drawdown_series ⇒ 看最大的虧損

# %%
# Max Drawdown 最大虧損
prices.to_drawdown_series().plot()
# Out:
# /Users/samhsiao/Documents/PythonVenv/envDash/lib/python3.9/site-packages/ffn/core.py:1232: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   drawdown = drawdown.fillna(method="ffill")
# <Axes: xlabel='Date'>

# %% [markdown]
# calc_stats ⇒ 統計報表

# %%
# 統計報表
stats = prices.calc_stats()
stats.display()
# Out:
# Stat                 spy         tlt
# -------------------  ----------  ----------
# Start                2021-01-04  2021-01-04
# End                  2023-12-08  2023-12-08
# Risk-free rate       0.00%       0.00%
#
# Total Return         29.93%      -35.67%
# Daily Sharpe         0.59        -0.76
# Daily Sortino        0.98        -1.30
# CAGR                 9.37%       -14.00%
# Max Drawdown         -24.50%     -44.05%
# Calmar Ratio         0.38        -0.32
#
# MTD                  0.83%       3.58%
# 3m                   3.66%       1.16%
# 6m                   8.02%       -5.67%
# YTD                  21.67%      -2.06%
# 1Y                   17.97%      -10.46%
# 3Y (ann.)            9.37%       -14.00%
# 5Y (ann.)            -           -
# 10Y (ann.)           -           -
# Since Incep. (ann.)  9.37%       -14.00%
#
# Daily Sharpe         0.59        -0.76
# Daily Sortino        0.98        -1.30
# Daily Mean (ann.)    10.51%      -13.49%
# Daily Vol (ann.)     17.71%      17.75%
# Daily Skew           -0.14       0.15
# Daily Kurt           1.63        0.13
# Best Day             5.50%       3.85%
# Worst Day            -4.35%      -3.42%
#
# Monthly Sharpe       0.59        -0.77
# Monthly Sortino      1.07        -1.29
# Monthly Mean (ann.)  10.41%      -12.52%
# Monthly Vol (ann.)   17.67%      16.32%
# Monthly Skew         -0.32       0.41
# Monthly Kurt         -0.73       -0.37
# Best Month           9.21%       9.92%
# Worst Month          -9.24%      -9.42%
#
# Yearly Sharpe        0.06        -0.81
# Yearly Sortino       0.14        -0.81
# Yearly Mean          1.75%       -16.65%
# Yearly Vol           28.18%      20.63%
# Yearly Skew          -           -
# Yearly Kurt          -           -
# Best Year            21.67%      -2.06%
# Worst Year           -18.18%     -31.23%
#
# Avg. Drawdown        -1.95%      -44.05%
# Avg. Drawdown Days   26.86       1067.00
# Avg. Up Month        4.15%       3.71%
# Avg. Down Month      -4.68%      -4.22%
# Win Year %           50.00%      0.00%
# Win 12m %            56.00%      8.00%
# /Users/samhsiao/Documents/PythonVenv/envDash/lib/python3.9/site-packages/ffn/core.py:1258: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return daily_prices[-1] / monthly_prices[-2] - 1
# /Users/samhsiao/Documents/PythonVenv/envDash/lib/python3.9/site-packages/ffn/core.py:1270: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return daily_prices[-1] / yearly_prices[-2] - 1
# /Users/samhsiao/Documents/PythonVenv/envDash/lib/python3.9/site-packages/ffn/core.py:232: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.total_return = obj[-1] / obj[0] - 1
# /Users/samhsiao/Documents/PythonVenv/envDash/lib/python3.9/site-packages/ffn/core.py:1232: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   drawdown = drawdown.fillna(method="ffill")
# /Users/samhsiao/Documents/PythonVenv/envDash/lib/python3.9/site-packages/ffn/core.py:308: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.return_table[fidx.year][fidx.month] = float(mp[0]) / dp[0] - 1
# /Users/samhsiao/Documents/PythonVenv/envDash/lib/python3.9/site-packages/ffn/core.py:322: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.three_month = dp[-1] / denom[-1] - 1
# /Users/samhsiao/Documents/PythonVenv/envDash/lib/python3.9/site-packages/ffn/core.py:341: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.six_month = dp[-1] / denom[-1] - 1
# /Users/samhsiao/Documents/PythonVenv/envDash/lib/python3.9/site-packages/ffn/core.py:355: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.one_year = dp[-1] / denom[-1] - 1
# /Users/samhsiao/Documents/PythonVenv/envDash/lib/python3.9/site-packages/ffn/core.py:384: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if mp[i] / mp[i - 11] > 1:
# /Users/samhsiao/Documents/PythonVenv/envDash/lib/python3.9/site-packages/ffn/core.py:1258: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return daily_prices[-1] / monthly_prices[-2] - 1
# /Users/samhsiao/Documents/PythonVenv/envDash/lib/python3.9/site-packages/ffn/core.py:1270: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return daily_prices[-1] / yearly_prices[-2] - 1
# /Users/samhsiao/Documents/PythonVenv/envDash/lib/python3.9/site-packages/ffn/core.py:232: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.total_return = obj[-1] / obj[0] - 1
# /Users/samhsiao/Documents/PythonVenv/envDash/lib/python3.9/site-packages/ffn/core.py:1232: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   drawdown = drawdown.fillna(method="ffill")
# /Users/samhsiao/Documents/PythonVenv/envDash/lib/python3.9/site-packages/ffn/core.py:308: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.return_table[fidx.year][fidx.month] = float(mp[0]) / dp[0] - 1
# /Users/samhsiao/Documents/PythonVenv/envDash/lib/python3.9/site-packages/ffn/core.py:322: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.three_month = dp[-1] / denom[-1] - 1
# /Users/samhsiao/Documents/PythonVenv/envDash/lib/python3.9/site-packages/ffn/core.py:341: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.six_month = dp[-1] / denom[-1] - 1
# /Users/samhsiao/Documents/PythonVenv/envDash/lib/python3.9/site-packages/ffn/core.py:355: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.one_year = dp[-1] / denom[-1] - 1
# /Users/samhsiao/Documents/PythonVenv/envDash/lib/python3.9/site-packages/ffn/core.py:384: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if mp[i] / mp[i - 11] > 1:

# %% [markdown]
# display_monthly_returns ⇒ 月報酬

# %%
print(stats['spy'].display_monthly_returns())
# Out:
#   Year    Jan    Feb    Mar    Apr    May    Jun    Jul    Aug    Sep    Oct    Nov    Dec     YTD
# ------  -----  -----  -----  -----  -----  -----  -----  -----  -----  -----  -----  -----  ------
#   2021   0.35   2.78   4.54   5.29   0.66   2.24   2.44   2.98  -4.66   7.02  -0.8    4.62   30.51
#   2022  -5.27  -2.95   3.76  -8.78   0.23  -8.25   9.21  -4.08  -9.24   8.13   5.56  -5.76  -18.18
#   2023   6.29  -2.51   3.71   1.6    0.46   6.48   3.27  -1.63  -4.74  -2.17   9.13   0.83   21.67
# None
