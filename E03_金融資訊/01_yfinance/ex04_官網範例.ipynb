# %% [markdown]
# 官網的範例

# %%
# 導入 yfinance 庫
import yfinance as yf  
# 創建一個 Ticker 物件代表微軟公司 (股票代碼：MSFT)
msft = yf.Ticker("MSFT")  

# 獲取所有股票信息
# 獲取微軟公司的所有股票信息
msft.info  

# 獲取歷史市場數據
# 獲取微軟公司過去一個月的歷史市場數據
hist = msft.history(period="1mo")  

# 顯示關於歷史數據的元信息（需要先調用 history() 方法）
# 顯示歷史數據的元信息
msft.history_metadata  

# 顯示行動（股息、分股、資本收益）
# 顯示微軟公司的所有行動（包括股息和分股）
msft.actions  
# 顯示微軟公司的股息
msft.dividends  
# 顯示微軟公司的分股
msft.splits  
# 顯示資本收益（僅限於共同基金和 ETFs）
msft.capital_gains  

# 顯示股票數量
# 從 2022 年 1 月 1 日開始的股票數量
msft.get_shares_full(start="2022-01-01", end=None)  

# 顯示財務報表：
# - 收益表
# 年度收益表
msft.income_stmt  
# 季度收益表
msft.quarterly_income_stmt  
# - 資產負債表
# 年度資產負債表
msft.balance_sheet  
# 季度資產負債表
msft.quarterly_balance_sheet  
# - 現金流量表
# 年度現金流量表
msft.cashflow  
# 季度現金流量表
msft.quarterly_cashflow  
# 更多選項見 `Ticker.get_income_stmt()`

# 顯示持有者
# 主要持有者
msft.major_holders  
# 機構持有者
msft.institutional_holders  
# 共同基金持有者
msft.mutualfund_holders  

# 顯示未來和歷史盈利日期，默認最多顯示接下來 4 個季度和最近 8 個季度的數據。
# 注意：如果需要更多數據，使用 msft.get_earnings_dates(limit=XX) 並增加 limit 參數。
msft.earnings_dates

# 顯示 ISIN 代碼 - *實驗性功能*
# ISIN = 國際證券識別碼
print(msft.isin)

# 顯示期權到期日
# 顯示微軟公司的期權到期日
print(msft.options)

# 顯示新聞
# 顯示有關微軟公司的最新新聞
print(msft.news)

# 獲取特定到期日的期權鏈
# 將 'YYYY-MM-DD' 替換為 '2023-12-15'
opt = msft.option_chain('2023-12-15')  
# 數據可通過：opt.calls, opt.puts 獲取
opt
# Out:
# -
# ('2023-12-15', '2023-12-22', '2023-12-29', '2024-01-05', '2024-01-12', '2024-01-19', '2024-01-26', '2024-02-16', '2024-03-15', '2024-04-19', '2024-05-17', '2024-06-21', '2024-07-19', '2024-09-20', '2024-12-20', '2025-01-17', '2025-06-20', '2025-12-19', '2026-01-16')
# [{'uuid': '1b9c4c77-7a13-3bcb-9704-c1de0d5e6eab', 'title': '10 Most Popular Technology Stocks Among Billionaires', 'publisher': 'Insider Monkey', 'link': 'https://finance.yahoo.com/news/10-most-popular-technology-stocks-190530918.html', 'providerPublishTime': 1702235130, 'type': 'STORY', 'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/yIzxMuNTBPmljNp72IjB0g--~B/aD04MTY7dz0xNDU2O2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/insidermonkey.com/9048e8b3b0db7d99f19ccbdad2029c4f', 'width': 1456, 'height': 816, 'tag': 'original'}, {'url': 'https://s.yimg.com/uu/api/res/1.2/hoJAxSgTwW1rmDv6wDhwFQ--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/insidermonkey.com/9048e8b3b0db7d99f19ccbdad2029c4f', 'width': 140, 'height': 140, 'tag': '140x140'}]}, 'relatedTickers': ['NVDA', 'AMD', 'MSFT', 'BABA', 'GOOG', 'MA', 'UBER', 'V', 'AMZN', 'CRM']}, {'uuid': '24a8badb-8dd2-317b-af02-b1412818c9e4', 'title': '12 Dow Stocks Billionaires Like The Most', 'publisher': 'Insider Monkey', 'link': 'https://finance.yahoo.com/news/12-dow-stocks-billionaires-most-180746813.html', 'providerPublishTime': 1702231666, 'type': 'STORY', 'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2
 'exchangeTimezoneName': 'America/New_York', 'exchangeTimezoneShortName': 'EST', 'gmtOffSetMilliseconds': -18000000, 'market': 'us_market', 'esgPopulated': False, 'regularMarketChangePercent': 0.56341726, 'regularMarketPrice': 373.04, 'firstTradeDateMilliseconds': 511108200000, 'priceHint': 2, 'postMarketChangePercent': -0.0641372, 'postMarketTime': 1702083595, 'postMarketPrice': 373.99, 'postMarketChange': -0.240021, 'regularMarketChange': 2.0899963, 'regularMarketTime': 1702069201, 'regularMarketDayHigh': 374.44, 'regularMarketDayRange': '368.28 - 374.44', 'regularMarketDayLow': 368.28, 'regularMarketVolume': 20154366, 'regularMarketPreviousClose': 370.95, 'bid': 0.0, 'ask': 0.0, 'bidSize': 8, 'askSize': 11, 'fullExchangeName': 'NasdaqGS', 'financialCurrency': 'USD', 'regularMarketOpen': 369.2, 'averageDailyVolume3Month': 24897574, 'averageDailyVolume10Day': 25474460, 'fiftyTwoWeekLowChange': 153.69, 'fiftyTwoWeekLowChangePercent': 0.70066106, 'fiftyTwoWeekRange': '219.35 - 384.3', 'fiftyTwoWeekHighChange': -11.259979, 'fiftyTwoWeekHighChangePercent': -0.029299973, 'fiftyTwoWeekLow': 219.35, 'fiftyTwoWeekHigh': 384.3, 'fiftyTwoWeekChangePercent': 48.20403, 'dividendDate': 1710374400, 'earningsTimestamp': 1698183000, 'earningsTimestampStart': 1705921140, 'earningsTimestampEnd': 1706270400, 'trailingAnnualDividendRate': 2.79, 'trailingPE': 36.112297, 'dividendRate': 3.0, 'trailingAnnualDividendYield': 0.007521229, 'dividendYield': 0.8, 'epsTrailingTwelveMonths': 10.33, 'epsForward': 12.96, 'epsCurrentYear': 11.24, 'priceEpsCurrentYear': 33.188614, 'sharesOutstanding': 7432260096, 'bookValue': 29.702, 'fiftyDayAverage': 350.3588, 'fiftyDayAverageChange': 22.681213, 'fiftyDayAverageChangePercent': 0.064737104, 'twoHundredDayAverage': 321.67636, 'twoHundredDayAverageChange': 51.363647, 'twoHundredDayAverageChangePercent': 0.15967493, 'marketCap': 2772530364416, 'forwardPE': 28.78395, 'priceToBook': 12.559424, 'sourceInterval': 15, 'exchangeDataDelayedBy': 0, 'averageAnalystRating': '1.7 - Buy', 'tradeable': False, 'cryptoTradeable': False, 'displayName': 'Microsoft', 'symbol': 'MSFT'})

# %% [markdown]
# 如果您想使用代理伺服器下載數據

# %%
import yfinance as yf

tickers = yf.Tickers('msft aapl goog')

# access each ticker using (example)
tickers.tickers['MSFT'].info
tickers.tickers['AAPL'].history(period="1mo")
tickers.tickers['GOOG'].actions
# Out:
#                            Dividends  Stock Splits
# Date
# 2014-03-27 00:00:00-04:00        0.0      2.002000
# 2015-04-27 00:00:00-04:00        0.0      1.002746
# 2022-07-18 00:00:00-04:00        0.0     20.000000

# %% [markdown]
# 要將價格歷史記錄下載到一張表中

# %%
import yfinance as yf
data = yf.download("SPY AAPL", period="1mo")
data
# Out:
# [*********************100%%**********************]  2 of 2 completed
#              Adj Close                   Close                    High  \
#                   AAPL         SPY        AAPL         SPY        AAPL
# Date
# 2023-11-09  182.169998  433.839996  182.410004  433.839996  184.119995
# 2023-11-10  186.399994  440.609985  186.399994  440.609985  186.570007
# 2023-11-13  184.800003  440.190002  184.800003  440.190002  186.029999
# 2023-11-24  24048300  29737400
# 2023-11-27  40552600  50506000
# 2023-11-28  38415400  62115000
# 2023-11-29  43014200  63146000
# 2023-11-30  48794400  79752700
# 2023-12-01  45679300  89097900
# 2023-12-04  43389500  72430900
# 2023-12-05  66628400  69793500
# 2023-12-06  41089700  69124700
# 2023-12-07  47477700  66995400
# 2023-12-08  53377300  83080900

# %% [markdown]
# 若要自訂請求，將 session= 參數傳遞給 Ticker 建構函數。

# %%
import requests_cache
session = requests_cache.CachedSession('yfinance.cache')
session.headers['User-agent'] = 'my-program/1.0'
ticker = yf.Ticker('msft', session=session)
# The scraped response will be stored in the cache
ticker.actions
# Out:
#                            Dividends  Stock Splits
# Date
# 1987-09-21 00:00:00-04:00       0.00           2.0
# 1990-04-16 00:00:00-04:00       0.00           2.0
# 1991-06-27 00:00:00-04:00       0.00           1.5
# 1992-06-15 00:00:00-04:00       0.00           1.5
# 1994-05-23 00:00:00-04:00       0.00           2.0
# ...                              ...           ...
# 2022-11-16 00:00:00-05:00       0.68           0.0
# 2023-02-15 00:00:00-05:00       0.68           0.0
# 2023-05-17 00:00:00-04:00       0.68           0.0
# 2023-08-16 00:00:00-04:00       0.68           0.0
# 2023-11-15 00:00:00-05:00       0.75           0.0
#
# [89 rows x 2 columns]

# %% [markdown]
# 將 requests_cache 與速率限制相結合，以避免觸發雅虎的速率限制器/阻止程序，從而損壞資料。

# %%
from requests import Session
from requests_cache import CacheMixin, SQLiteCache
from requests_ratelimiter import LimiterMixin, MemoryQueueBucket
from pyrate_limiter import Duration, RequestRate, Limiter
class CachedLimiterSession(CacheMixin, LimiterMixin, Session):
    pass

session = CachedLimiterSession(
    limiter=Limiter(RequestRate(2, Duration.SECOND*5)),  # max 2 requests per 5 seconds
    bucket_class=MemoryQueueBucket,
    backend=SQLiteCache("yfinance.cache"),
)
# Out:
# <CachedSession(cache=<SQLiteCache(name=http_cache)>, settings=CacheSettings(always_revalidate=False, expire_after=-1))>

# %%
from pandas_datareader import data as pdr

import yfinance as yf
yf.pdr_override() # <== that's all it takes :-)

# download dataframe
data = pdr.get_data_yahoo("SPY", start="2017-01-01", end="2017-04-30")
data
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-01-03  225.039993  225.830002  223.880005  225.240005  200.629684
# 2017-01-04  225.619995  226.750000  225.610001  226.580002  201.823257
# 2017-01-05  226.270004  226.580002  225.479996  226.399994  201.662949
# 2017-01-06  226.529999  227.750000  225.899994  227.210007  202.384491
# 2017-01-09  226.910004  227.070007  226.419998  226.460007  201.716415
# ...                ...         ...         ...         ...         ...
# 2017-04-24  237.179993  237.410004  234.559998  237.169998  212.175217
# 2017-04-25  237.910004  238.949997  237.809998  238.550003  213.409821
# 2017-04-26  238.509995  239.529999  238.350006  238.399994  213.275589
# 2017-04-27  238.770004  238.949997  237.979996  238.600006  213.454529
# 2017-04-28  238.899994  238.929993  237.929993  238.080002  212.989304
#
#                Volume
# Date
# 2017-01-03   91366500
# 2017-01-04   78744400
# 2017-01-05   78379000
# 2017-01-06   71559900
# 2017-01-09   46939700
# ...               ...
# 2017-04-24  119209900
# 2017-04-25   76698300
# 2017-04-26   84702500
# 2017-04-27   57410300
# 2017-04-28   63532800
#
# [81 rows x 6 columns]
