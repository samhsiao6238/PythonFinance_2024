# %% [markdown]
# 集成於 yfinance，使用相同資料

# %%
# %pip install ffn

# %% [markdown]
# 要捉 SPY 2021年以後的資料

# %%
import ffn
# ffn 取得 股價
prices = ffn.get('spy', start='2021-01-01')
prices[0: 10]
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                    spy
# Date
# 2021-01-04  354.197357
# 2021-01-05  356.636902
# 2021-01-06  358.769043
# 2021-01-07  364.099487
# 2021-01-08  366.173981
# 2021-01-11  363.705688
# 2021-01-12  363.782562
# 2021-01-13  364.762146
# 2021-01-14  363.484802
# 2021-01-15  360.833984

# %% [markdown]
# 若出現錯誤訊息 TypeError: string indices must be integers

# %%
import yfinance
yfinance.pdr_override()

# %% [markdown]
# rebase ⇒ 將初始價格改為 100，可以比較兩個以上的股價漲跌變化

# %%
prices = ffn.get('spy, tlt', start='2021-01-01')
# rebase 股價繪圖
# %matplotlib inline
prices.rebase().plot()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# <Axes: xlabel='Date'>

# %% [markdown]
# to_drawdown_series ⇒ 看最大的虧損

# %%
# Max Drawdown 最大虧損
prices.to_drawdown_series().plot()
# Out:
# /Users/samhsiao/Documents/PythonVenv/envDash/lib/python3.10/site-packages/ffn/core.py:1232: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   drawdown = drawdown.fillna(method="ffill")
# <Axes: xlabel='Date'>

# %% [markdown]
# calc_stats ⇒ 統計報表

# %%
# 統計報表
stats = prices.calc_stats()
stats.display()
# Out:
# Stat                 spy         tlt
# -------------------  ----------  ----------
# Start                2021-01-04  2021-01-04
# End                  2023-12-12  2023-12-12
# Risk-free rate       0.00%       0.00%
#
# Total Return         31.03%      -35.62%
# Daily Sharpe         0.61        -0.76
# Daily Sortino        1.01        -1.30
# CAGR                 9.64%       -13.93%
# Max Drawdown         -24.50%     -44.05%
# Calmar Ratio         0.39        -0.32
#
# MTD                  1.69%       3.67%
# 3m                   4.43%       1.40%
# 6m                   7.76%       -5.73%
# YTD                  22.70%      -1.98%
# 1Y                   18.16%      -8.29%
# 3Y (ann.)            9.64%       -13.93%
# 5Y (ann.)            -           -
# 10Y (ann.)           -           -
# Since Incep. (ann.)  9.64%       -13.93%
#
# Daily Sharpe         0.61        -0.76
# Daily Sortino        1.01        -1.30
# Daily Mean (ann.)    10.77%      -13.42%
# Daily Vol (ann.)     17.68%      17.73%
# Daily Skew           -0.14       0.15
# Daily Kurt           1.64        0.14
# Best Day             5.50%       3.85%
# Worst Day            -4.35%      -3.42%
#
# Monthly Sharpe       0.61        -0.77
# Monthly Sortino      1.10        -1.29
# Monthly Mean (ann.)  10.71%      -12.49%
# Monthly Vol (ann.)   17.68%      16.33%
# Monthly Skew         -0.33       0.41
# Monthly Kurt         -0.72       -0.37
# Best Month           9.21%       9.92%
# Worst Month          -9.24%      -9.42%
#
# Yearly Sharpe        0.08        -0.80
# Yearly Sortino       0.18        -0.80
# Yearly Mean          2.26%       -16.60%
# Yearly Vol           28.91%      20.69%
# Yearly Skew          -           -
# Yearly Kurt          -           -
# Best Year            22.70%      -1.98%
# Worst Year           -18.18%     -31.23%
#
# Avg. Drawdown        -1.95%      -44.05%
# Avg. Drawdown Days   26.97       1071.00
# Avg. Up Month        4.19%       3.72%
# Avg. Down Month      -4.68%      -4.22%
# Win Year %           50.00%      0.00%
# Win 12m %            56.00%      8.00%
# /Users/samhsiao/Documents/PythonVenv/envDash/lib/python3.10/site-packages/ffn/core.py:1258: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return daily_prices[-1] / monthly_prices[-2] - 1
# /Users/samhsiao/Documents/PythonVenv/envDash/lib/python3.10/site-packages/ffn/core.py:1270: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return daily_prices[-1] / yearly_prices[-2] - 1
# /Users/samhsiao/Documents/PythonVenv/envDash/lib/python3.10/site-packages/ffn/core.py:232: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.total_return = obj[-1] / obj[0] - 1
# /Users/samhsiao/Documents/PythonVenv/envDash/lib/python3.10/site-packages/ffn/core.py:1232: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   drawdown = drawdown.fillna(method="ffill")
# /Users/samhsiao/Documents/PythonVenv/envDash/lib/python3.10/site-packages/ffn/core.py:308: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.return_table[fidx.year][fidx.month] = float(mp[0]) / dp[0] - 1
# /Users/samhsiao/Documents/PythonVenv/envDash/lib/python3.10/site-packages/ffn/core.py:322: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.three_month = dp[-1] / denom[-1] - 1
# /Users/samhsiao/Documents/PythonVenv/envDash/lib/python3.10/site-packages/ffn/core.py:341: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.six_month = dp[-1] / denom[-1] - 1
# /Users/samhsiao/Documents/PythonVenv/envDash/lib/python3.10/site-packages/ffn/core.py:355: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.one_year = dp[-1] / denom[-1] - 1
# /Users/samhsiao/Documents/PythonVenv/envDash/lib/python3.10/site-packages/ffn/core.py:384: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if mp[i] / mp[i - 11] > 1:
# /Users/samhsiao/Documents/PythonVenv/envDash/lib/python3.10/site-packages/ffn/core.py:1258: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return daily_prices[-1] / monthly_prices[-2] - 1
# /Users/samhsiao/Documents/PythonVenv/envDash/lib/python3.10/site-packages/ffn/core.py:1270: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return daily_prices[-1] / yearly_prices[-2] - 1
# /Users/samhsiao/Documents/PythonVenv/envDash/lib/python3.10/site-packages/ffn/core.py:232: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.total_return = obj[-1] / obj[0] - 1
# /Users/samhsiao/Documents/PythonVenv/envDash/lib/python3.10/site-packages/ffn/core.py:1232: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   drawdown = drawdown.fillna(method="ffill")
# /Users/samhsiao/Documents/PythonVenv/envDash/lib/python3.10/site-packages/ffn/core.py:308: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.return_table[fidx.year][fidx.month] = float(mp[0]) / dp[0] - 1
# /Users/samhsiao/Documents/PythonVenv/envDash/lib/python3.10/site-packages/ffn/core.py:322: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.three_month = dp[-1] / denom[-1] - 1
# /Users/samhsiao/Documents/PythonVenv/envDash/lib/python3.10/site-packages/ffn/core.py:341: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.six_month = dp[-1] / denom[-1] - 1
# /Users/samhsiao/Documents/PythonVenv/envDash/lib/python3.10/site-packages/ffn/core.py:355: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.one_year = dp[-1] / denom[-1] - 1
# /Users/samhsiao/Documents/PythonVenv/envDash/lib/python3.10/site-packages/ffn/core.py:384: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if mp[i] / mp[i - 11] > 1:

# %% [markdown]
# display_monthly_returns ⇒ 月報酬

# %%
print(stats['spy'].display_monthly_returns())
# Out:
#   Year    Jan    Feb    Mar    Apr    May    Jun    Jul    Aug    Sep    Oct    Nov    Dec     YTD
# ------  -----  -----  -----  -----  -----  -----  -----  -----  -----  -----  -----  -----  ------
#   2021   0.35   2.78   4.54   5.29   0.66   2.24   2.44   2.98  -4.66   7.02  -0.8    4.62   30.51
#   2022  -5.27  -2.95   3.76  -8.78   0.23  -8.25   9.21  -4.08  -9.24   8.13   5.56  -5.76  -18.18
#   2023   6.29  -2.51   3.71   1.6    0.46   6.48   3.27  -1.63  -4.74  -2.17   9.13   1.69   22.7
# None
