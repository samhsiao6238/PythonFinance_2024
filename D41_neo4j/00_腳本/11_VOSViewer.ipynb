# %%
import networkx as nx
draw_g = nx.Graph()  
edge_list = [('关键词', '上班'),
('吃饭', '上班'),
('睡觉', '上班'),
('追剧', '吃饭')]

draw_g.add_edges_from(edge_list)
nx.draw(draw_g)
pos=nx.spring_layout(draw_g)
pos
# Out:
# {'关键词': array([-0.76649018,  0.36752532]),
#  '上班': array([-0.12535842,  0.22908779]),
#  '吃饭': array([ 0.2333597 , -0.43552439]),
#  '睡觉': array([0.1182933 , 0.83891128]),
#  '追剧': array([ 0.5401956, -1.       ])}
