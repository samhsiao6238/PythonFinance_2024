# %%
import networkx as nx
draw_g = nx.Graph()  
edge_list = [('關鍵字', '上班'),
('吃飯', '上班'),
('睡覺', '上班'),
('追劇', '吃飯')]

draw_g.add_edges_from(edge_list)
nx.draw(draw_g)
pos=nx.spring_layout(draw_g)
pos
# Out:
# {'關鍵字': array([-0.53677166, -0.53248468]),
#  '上班': array([-0.03534899, -0.22735055]),
#  '吃飯': array([0.06906854, 0.4320138 ]),
#  '睡覺': array([ 0.34459158, -0.67217856]),
#  '追劇': array([0.15846053, 1.        ])}
