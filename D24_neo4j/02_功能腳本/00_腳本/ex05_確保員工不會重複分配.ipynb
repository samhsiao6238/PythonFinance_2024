# %% [markdown]
# ## 修正腳本，確保每個員工只有一個組織關係

# %%
from neo4j import GraphDatabase

# 設定 Neo4j 資料庫的 URI 和認證資訊
URI = "neo4j+s://bfc46ed1.databases.neo4j.io"
AUTH = ("neo4j", "8Yc-sCEfoQN5XjrKlV4VqqMilhv6HM4jLrwzLf2P-Ic")
# 設定每個組織的員工人數上限
employee_threshold = 10

def main():
    # 上下文管理：使用 GraphDatabase 連接到 Neo4j 資料庫
    with GraphDatabase.driver(URI, auth=AUTH) as driver:
        # 建立會話
        with driver.session(database="neo4j") as session:
            # 重複 100 次，也就是添加 100 個員工
            for i in range(100):
                # 生成員工名稱，這裡以 `Thor` 最為前綴、序號作為後綴
                name = f"Thor{i}"
                # 執行寫入交易，添加員工並獲取組織 ID
                org_id = session.execute_write(employ_person_tx, name)
                # 輸出結果
                print(f"將員工 {name} 加入組織 {org_id}")

            # 統計並顯示資料庫中的資訊
            display_database_statistics(session)

def employ_person_tx(tx, name):
    # 使用 `MERGE` 達成如果已存在則不重複建立
    result = tx.run("""
        MERGE (p:Person {name: $name})
        RETURN p.name AS name
        """, name=name
    )

    # 確保每個人只有一個 `WORKS_FOR` 關係
    result = tx.run("""
        MATCH (p:Person {name: $name})-[:WORKS_FOR]->(o:Organization)
        RETURN o.id AS id, COUNT{(p)-[r:WORKS_FOR]->(o)} AS employees_n
        LIMIT 1
    """, name=name)
    
    org = result.single()

    if org is None:
        # 獲取最近建立的組織 ID 及其相關聯的員工數量
        result = tx.run("""
            MATCH (o:Organization)
            RETURN o.id AS id, COUNT{(p:Person)-[r:WORKS_FOR]->(o)} AS employees_n
            ORDER BY o.created_date DESC
            LIMIT 1
        """)
        org = result.single()

        # 如果最近的組織沒有員工，則拋出異常
        if org is not None and org["employees_n"] == 0:
            raise Exception("最新建立的組織是空的。")
            # 交易將回滾 -> 連 Person 都不會建立!

        # 如果組織員工數未達上限，將該員工添加到該組織
        if org is not None and org.get("employees_n") < employee_threshold:
            result = tx.run("""
                MATCH (o:Organization {id: $org_id})
                MATCH (p:Person {name: $name})
                MERGE (p)-[r:WORKS_FOR]->(o)
                RETURN $org_id AS id
                """, org_id=org["id"], name=name
            )
        # 如果組織員工數已達上限，建立一個新的組織並將該員工添加到新組織
        else:
            result = tx.run("""
                MATCH (p:Person {name: $name})
                CREATE (o:Organization {id: randomuuid(), created_date: datetime()})
                MERGE (p)-[r:WORKS_FOR]->(o)
                RETURN o.id AS id
                """, name=name
            )

        # 傳出：新員工所屬的組織 ID
        return result.single()["id"]
    else:
        # 如果該員工已經有一個 `WORKS_FOR` 關係，直接返回組織 ID
        return org["id"]

def display_database_statistics(session):
    """統計並顯示資料庫中的資訊"""
    # 查詢總節點數量
    node_count_result = session.run("MATCH (n) RETURN COUNT(n) AS node_count")
    node_count = node_count_result.single()["node_count"]
    
    # 查詢總關係數量
    relationship_count_result = session.run("MATCH ()-[r]->() RETURN COUNT(r) AS relationship_count")
    relationship_count = relationship_count_result.single()["relationship_count"]
    
    # 查詢各類型節點數量
    node_labels_result = session.run("MATCH (n) RETURN DISTINCT labels(n) AS labels, COUNT(n) AS count")
    node_labels = node_labels_result.data()
    
    # 查詢各類型關係數量
    relationship_types_result = session.run("MATCH ()-[r]->() RETURN TYPE(r) AS type, COUNT(r) AS count")
    relationship_types = relationship_types_result.data()

    # 顯示結果
    print(f"總節點數量: {node_count}")
    print(f"總關係數量: {relationship_count}")
    print("各類型節點數量:")
    for record in node_labels:
        print(f"{record['labels']}: {record['count']}")
    print("各類型關係數量:")
    for record in relationship_types:
        print(f"{record['type']}: {record['count']}")

if __name__ == "__main__":
    main()
# Out:
# 將員工 Thor0 加入組織 621c1058-e34f-4e34-a0c9-2d6298c8e8b5
# 將員工 Thor1 加入組織 621c1058-e34f-4e34-a0c9-2d6298c8e8b5
# 將員工 Thor2 加入組織 621c1058-e34f-4e34-a0c9-2d6298c8e8b5
# 將員工 Thor3 加入組織 621c1058-e34f-4e34-a0c9-2d6298c8e8b5
# 將員工 Thor4 加入組織 621c1058-e34f-4e34-a0c9-2d6298c8e8b5
# 將員工 Thor5 加入組織 621c1058-e34f-4e34-a0c9-2d6298c8e8b5
# 將員工 Thor6 加入組織 621c1058-e34f-4e34-a0c9-2d6298c8e8b5
# 將員工 Thor7 加入組織 621c1058-e34f-4e34-a0c9-2d6298c8e8b5
# 將員工 Thor8 加入組織 621c1058-e34f-4e34-a0c9-2d6298c8e8b5
# 將員工 Thor9 加入組織 621c1058-e34f-4e34-a0c9-2d6298c8e8b5
# 將員工 Thor10 加入組織 fcc816b7-5c50-4d3a-8aed-922dc6669f70
# 將員工 Thor11 加入組織 fcc816b7-5c50-4d3a-8aed-922dc6669f70
# 將員工 Thor12 加入組織 fcc816b7-5c50-4d3a-8aed-922dc6669f70
# 將員工 Thor13 加入組織 fcc816b7-5c50-4d3a-8aed-922dc6669f70
# 將員工 Thor14 加入組織 fcc816b7-5c50-4d3a-8aed-922dc6669f70
# 將員工 Thor15 加入組織 fcc816b7-5c50-4d3a-8aed-922dc6669f70
# 將員工 Thor16 加入組織 fcc816b7-5c50-4d3a-8aed-922dc6669f70
# 將員工 Thor17 加入組織 fcc816b7-5c50-4d3a-8aed-922dc6669f70
# 將員工 Thor18 加入組織 fcc816b7-5c50-4d3a-8aed-922dc6669f70
# 將員工 Thor19 加入組織 fcc816b7-5c50-4d3a-8aed-922dc6669f70
# 將員工 Thor20 加入組織 ba8f9b0a-c05a-49c6-ac2c-06573cf0f445
# 將員工 Thor21 加入組織 ba8f9b0a-c05a-49c6-ac2c-06573cf0f445
# 將員工 Thor22 加入組織 ba8f9b0a-c05a-49c6-ac2c-06573cf0f445
# 將員工 Thor23 加入組織 ba8f9b0a-c05a-49c6-ac2c-06573cf0f445
# 將員工 Thor24 加入組織 ba8f9b0a-c05a-49c6-ac2c-06573cf0f445
# 將員工 Thor25 加入組織 ba8f9b0a-c05a-49c6-ac2c-06573cf0f445
# 將員工 Thor26 加入組織 ba8f9b0a-c05a-49c6-ac2c-06573cf0f445
# 將員工 Thor27 加入組織 ba8f9b0a-c05a-49c6-ac2c-06573cf0f445
# 將員工 Thor28 加入組織 ba8f9b0a-c05a-49c6-ac2c-06573cf0f445
# 將員工 Thor29 加入組織 ba8f9b0a-c05a-49c6-ac2c-06573cf0f445
# 將員工 Thor30 加入組織 041ad58a-d2bb-496c-99a1-ef47e052bda1
# 將員工 Thor31 加入組織 041ad58a-d2bb-496c-99a1-ef47e052bda1
# 將員工 Thor32 加入組織 041ad58a-d2bb-496c-99a1-ef47e052bda1
# 將員工 Thor33 加入組織 041ad58a-d2bb-496c-99a1-ef47e052bda1
# 將員工 Thor34 加入組織 041ad58a-d2bb-496c-99a1-ef47e052bda1
# 將員工 Thor35 加入組織 041ad58a-d2bb-496c-99a1-ef47e052bda1
# 將員工 Thor36 加入組織 041ad58a-d2bb-496c-99a1-ef47e052bda1
# 將員工 Thor37 加入組織 041ad58a-d2bb-496c-99a1-ef47e052bda1
# 將員工 Thor38 加入組織 041ad58a-d2bb-496c-99a1-ef47e052bda1
# 將員工 Thor39 加入組織 041ad58a-d2bb-496c-99a1-ef47e052bda1
# 將員工 Thor40 加入組織 b7244d99-b910-450f-ac7d-1cadb7563f3b
# 將員工 Thor41 加入組織 b7244d99-b910-450f-ac7d-1cadb7563f3b
# 將員工 Thor42 加入組織 b7244d99-b910-450f-ac7d-1cadb7563f3b
# 將員工 Thor43 加入組織 b7244d99-b910-450f-ac7d-1cadb7563f3b
# 將員工 Thor44 加入組織 b7244d99-b910-450f-ac7d-1cadb7563f3b
# 將員工 Thor45 加入組織 b7244d99-b910-450f-ac7d-1cadb7563f3b
# 將員工 Thor46 加入組織 b7244d99-b910-450f-ac7d-1cadb7563f3b
# 將員工 Thor47 加入組織 b7244d99-b910-450f-ac7d-1cadb7563f3b
# 將員工 Thor48 加入組織 b7244d99-b910-450f-ac7d-1cadb7563f3b
# 將員工 Thor49 加入組織 b7244d99-b910-450f-ac7d-1cadb7563f3b
# 將員工 Thor50 加入組織 f521b36a-3056-4e86-8cc5-1b31cb82b47c
# 將員工 Thor51 加入組織 f521b36a-3056-4e86-8cc5-1b31cb82b47c
# 將員工 Thor52 加入組織 f521b36a-3056-4e86-8cc5-1b31cb82b47c
# 將員工 Thor53 加入組織 f521b36a-3056-4e86-8cc5-1b31cb82b47c
# 將員工 Thor54 加入組織 f521b36a-3056-4e86-8cc5-1b31cb82b47c
# 將員工 Thor55 加入組織 f521b36a-3056-4e86-8cc5-1b31cb82b47c
# 將員工 Thor56 加入組織 f521b36a-3056-4e86-8cc5-1b31cb82b47c
# 將員工 Thor57 加入組織 f521b36a-3056-4e86-8cc5-1b31cb82b47c
# 將員工 Thor58 加入組織 f521b36a-3056-4e86-8cc5-1b31cb82b47c
# 將員工 Thor59 加入組織 f521b36a-3056-4e86-8cc5-1b31cb82b47c
# 將員工 Thor60 加入組織 46931516-1240-4645-8270-33912e711912
# 將員工 Thor61 加入組織 46931516-1240-4645-8270-33912e711912
# 將員工 Thor62 加入組織 46931516-1240-4645-8270-33912e711912
# 將員工 Thor63 加入組織 46931516-1240-4645-8270-33912e711912
# 將員工 Thor64 加入組織 46931516-1240-4645-8270-33912e711912
# 將員工 Thor65 加入組織 46931516-1240-4645-8270-33912e711912
# 將員工 Thor66 加入組織 46931516-1240-4645-8270-33912e711912
# 將員工 Thor67 加入組織 46931516-1240-4645-8270-33912e711912
# 將員工 Thor68 加入組織 46931516-1240-4645-8270-33912e711912
# 將員工 Thor69 加入組織 46931516-1240-4645-8270-33912e711912
# 將員工 Thor70 加入組織 06a90295-3b52-4101-8e64-a10073598148
# 將員工 Thor71 加入組織 06a90295-3b52-4101-8e64-a10073598148
# 將員工 Thor72 加入組織 06a90295-3b52-4101-8e64-a10073598148
# 將員工 Thor73 加入組織 06a90295-3b52-4101-8e64-a10073598148
# 將員工 Thor74 加入組織 06a90295-3b52-4101-8e64-a10073598148
# 將員工 Thor75 加入組織 06a90295-3b52-4101-8e64-a10073598148
# 將員工 Thor76 加入組織 06a90295-3b52-4101-8e64-a10073598148
# 將員工 Thor77 加入組織 06a90295-3b52-4101-8e64-a10073598148
# 將員工 Thor78 加入組織 06a90295-3b52-4101-8e64-a10073598148
# 將員工 Thor79 加入組織 06a90295-3b52-4101-8e64-a10073598148
# 將員工 Thor80 加入組織 f0aa583d-3ca1-4897-817e-c550a248c796
# 將員工 Thor81 加入組織 f0aa583d-3ca1-4897-817e-c550a248c796
# 將員工 Thor82 加入組織 f0aa583d-3ca1-4897-817e-c550a248c796
# 將員工 Thor83 加入組織 f0aa583d-3ca1-4897-817e-c550a248c796
# 將員工 Thor84 加入組織 f0aa583d-3ca1-4897-817e-c550a248c796
# 將員工 Thor85 加入組織 f0aa583d-3ca1-4897-817e-c550a248c796
# 將員工 Thor86 加入組織 f0aa583d-3ca1-4897-817e-c550a248c796
# 將員工 Thor87 加入組織 f0aa583d-3ca1-4897-817e-c550a248c796
# 將員工 Thor88 加入組織 f0aa583d-3ca1-4897-817e-c550a248c796
# 將員工 Thor89 加入組織 f0aa583d-3ca1-4897-817e-c550a248c796
# 將員工 Thor90 加入組織 073e4370-704b-4c75-b084-8a06d2cedc6c
# 將員工 Thor91 加入組織 073e4370-704b-4c75-b084-8a06d2cedc6c
# 將員工 Thor92 加入組織 073e4370-704b-4c75-b084-8a06d2cedc6c
# 將員工 Thor93 加入組織 073e4370-704b-4c75-b084-8a06d2cedc6c
# 將員工 Thor94 加入組織 073e4370-704b-4c75-b084-8a06d2cedc6c
# 將員工 Thor95 加入組織 073e4370-704b-4c75-b084-8a06d2cedc6c
# 將員工 Thor96 加入組織 073e4370-704b-4c75-b084-8a06d2cedc6c
# 將員工 Thor97 加入組織 073e4370-704b-4c75-b084-8a06d2cedc6c
# 將員工 Thor98 加入組織 073e4370-704b-4c75-b084-8a06d2cedc6c
# 將員工 Thor99 加入組織 073e4370-704b-4c75-b084-8a06d2cedc6c
# 總節點數量: 110
# 總關係數量: 100
# 各類型節點數量:
# ['Person']: 100
# ['Organization']: 10
# 各類型關係數量:
# WORKS_FOR: 100
