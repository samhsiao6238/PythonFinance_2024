# %%
import os
import nest_asyncio
import streamlit as st

os.environ["OPENAI_API_KEY"] = st.secrets["OPENAI_API_KEY"]
# 這是在筆記本中運行的工具
nest_asyncio.apply()

# %%
# 下載 UBER 10-K 文件
# !mkdir data
# !wget "https://www.dropbox.com/s/948jr9cfs7fgj99/UBER.zip?dl=1" -O data/UBER.zip
# !unzip data/UBER.zip -d data
# Out:
# --2024-05-31 03:48:17--  https://www.dropbox.com/s/948jr9cfs7fgj99/UBER.zip?dl=1
# 正在查找主機 www.dropbox.com (www.dropbox.com)... 162.125.85.18
# 正在連接 www.dropbox.com (www.dropbox.com)|162.125.85.18|:443... 連上了。
# 已送出 HTTP 要求，正在等候回應... 302 Found
# 位置: /scl/fi/vetj6tgcux8e309swquxs/UBER.zip?rlkey=oy4vx60rplorounkh9wh2waux&dl=1 [跟隨至新的 URL]
# --2024-05-31 03:48:17--  https://www.dropbox.com/scl/fi/vetj6tgcux8e309swquxs/UBER.zip?rlkey=oy4vx60rplorounkh9wh2waux&dl=1
# 繼續使用和 www.dropbox.com:443 的連線。
# 已送出 HTTP 要求，正在等候回應... 302 Found
# 位置: https://uc09fdca175f3797d1d3ebc3a8eb.dl.dropboxusercontent.com/cd/0/inline/CT4ynsdCUOa4ch2dkXNbkS_tQIgkYeeCJrP9XhFZLyh0qDwkpWWNB87zRKn_-KI9JNSaTnBq_G23jVfQE4BDio7vc_qRaX3-jxOIy5-hgwiszV1cQbr-BehheFulUL0x5kc/file?dl=1# [跟隨至新的 URL]
# --2024-05-31 03:48:18--  https://uc09fdca175f3797d1d3ebc3a8eb.dl.dropboxusercontent.com/cd/0/inline/CT4ynsdCUOa4ch2dkXNbkS_tQIgkYeeCJrP9XhFZLyh0qDwkpWWNB87zRKn_-KI9JNSaTnBq_G23jVfQE4BDio7vc_qRaX3-jxOIy5-hgwiszV1cQbr-BehheFulUL0x5kc/file?dl=1
# 正在查找主機 uc09fdca175f3797d1d3ebc3a8eb.dl.dropboxusercontent.com (uc09fdca175f3797d1d3ebc3a8eb.dl.dropboxusercontent.com)... 162.125.85.15
# 正在連接 uc09fdca175f3797d1d3ebc3a8eb.dl.dropboxusercontent.com (uc09fdca175f3797d1d3ebc3a8eb.dl.dropboxusercontent.com)|162.125.85.15|:443... 連上了。
# 已送出 HTTP 要求，正在等候回應... 302 Found
# 位置: /cd/0/inline2/CT4RbRxNzbqbvs2ClDRrp3WMvUPe6RDsrRIzEE6JEvEquXCQkJFCfNqwhFVtGX5DlavV9yhek9hci18c1ge0Mkp4AhYQY9twm-YAZ_BERfJkTpgsSZkHeDRt1_SD3hmJSDbNSlB57a4BIqKStAFGCkiXJDP748PaAVSBAV08JNwNi5CkcwKR1av6cpOT6q_XvqGu9V6FYTHrucXL3QUN6zeyjt1jZt2NPq0tCZzVwS6_VQfhRzaJS1Cb9AXtBlsgNp5ddBp4mwEgQZ9RfAHVjDQ58kD8fQ2GaQqFMfbfirvCJ0bOP3wE9KGuG2fLMZNwM2TVf5eYANzwBJDvqjX_j9D-z0Jrlv_Q-JSl06_uU4Adnw/file?dl=1 [跟隨至新的 URL]
# --2024-05-31 03:48:18--  https://uc09fdca175f3797d1d3ebc3a8eb.dl.dropboxusercontent.com/cd/0/inline2/CT4RbRxNzbqbvs2ClDRrp3WMvUPe6RDsrRIzEE6JEvEquXCQkJFCfNqwhFVtGX5DlavV9yhek9hci18c1ge0Mkp4AhYQY9twm-YAZ_BERfJkTpgsSZkHeDRt1_SD3hmJSDbNSlB57a4BIqKStAFGCkiXJDP748PaAVSBAV08JNwNi5CkcwKR1av6cpOT6q_XvqGu9V6FYTHrucXL3QUN6zeyjt1jZt2NPq0tCZzVwS6_VQfhRzaJS1Cb9AXtBlsgNp5ddBp4mwEgQZ9RfAHVjDQ58kD8fQ2GaQqFMfbfirvCJ0bOP3wE9KGuG2fLMZNwM2TVf5eYANzwBJDvqjX_j9D-z0Jrlv_Q-JSl06_uU4Adnw/file?dl=1
# 繼續使用和 uc09fdca175f3797d1d3ebc3a8eb.dl.dropboxusercontent.com:443 的連線。
# 已送出 HTTP 要求，正在等候回應... 200 OK
# 長度: 1820227 (1.7M) [application/binary]
# 儲存到：「data/UBER.zip」
#
# data/UBER.zip       100%[===================>]   1.74M  --.-KB/s  於 0.1s
#
# 2024-05-31 03:48:19 (13.8 MB/s) - 已儲存 「data/UBER.zip」 [1820227/1820227]
#
# Archive:  data/UBER.zip
#    creating: data/UBER/
#   inflating: data/UBER/UBER_2021.html
#   inflating: data/__MACOSX/UBER/._UBER_2021.html
#   inflating: data/UBER/UBER_2020.html
#   inflating: data/__MACOSX/UBER/._UBER_2020.html
#   inflating: data/UBER/UBER_2019.html
#   inflating: data/__MACOSX/UBER/._UBER_2019.html
#   inflating: data/UBER/UBER_2022.html
#   inflating: data/__MACOSX/UBER/._UBER_2022.html

# %%
from llama_index.readers.file import UnstructuredReader
from pathlib import Path

# 這個壓縮檔中有四個年度的資料
years = [2022, 2021, 2020, 2019]

loader = UnstructuredReader()
doc_set = {}
all_docs = []
for year in years:
    year_docs = loader.load_data(
        file=Path(f"./data/UBER/UBER_{year}.html"),
        split_documents=False
    )
    for d in year_docs:
        d.metadata = {"year": year}
    doc_set[year] = year_docs
    all_docs.extend(year_docs)

# %%
from llama_index.core import VectorStoreIndex, StorageContext
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.llms.openai import OpenAI
from llama_index.core import Settings

Settings.chunk_size = 512
Settings.chunk_overlap = 64
Settings.llm = OpenAI(
    model=st.secrets["OPENAI_MODEL"]
)
Settings.embed_model = OpenAIEmbedding(
    model=st.secrets["OPENAI_EMBEDDING_MODEL"]
)

index_set = {}
for year in years:
    storage_context = StorageContext.from_defaults()
    cur_index = VectorStoreIndex.from_documents(
        doc_set[year],
        storage_context=storage_context
    )
    index_set[year] = cur_index
    storage_context.persist(persist_dir=f"./storage/{year}")

# %%
from llama_index.core import load_index_from_storage

index_set = {}
for year in years:
    storage_context = StorageContext.from_defaults(persist_dir=f"./storage/{year}")
    cur_index = load_index_from_storage(storage_context)
    index_set[year] = cur_index

# %%
from llama_index.core.tools import QueryEngineTool, ToolMetadata
from llama_index.core.query_engine import SubQuestionQueryEngine

individual_query_engine_tools = [
    QueryEngineTool(
        query_engine=index_set[year].as_query_engine(),
        metadata=ToolMetadata(
            name=f"vector_index_{year}",
            description=(
                f"當您想要回答有關 Uber {year} SEC 10-K 的查詢時非常有用"
            )
        )
    ) for year in years
]

query_engine = SubQuestionQueryEngine.from_defaults(
    query_engine_tools=individual_query_engine_tools
)

# %%
from llama_index.agent.openai import OpenAIAgent

query_engine_tool = QueryEngineTool(
    query_engine=query_engine,
    metadata=ToolMetadata(
        name="sub_question_query_engine",
        description=(
            "當您想要回答需要分析 Uber 的多個 SEC 10-K 文件的查詢時非常有用"
        )
    )
)

tools = individual_query_engine_tools + [query_engine_tool]

agent = OpenAIAgent.from_tools(tools, verbose=True)

# %%
# 預設問題來取得回答
response = agent.chat("哈囉，我是小柱子")
print(str(response))

# 預設問題來取得回答
response = agent.chat(
    "2020 年 Uber 面臨的最大風險因素有哪些？"
)
# 輸出答案
print(str(response))

# 預設問題
cross_query_str = (
    "比較/對比多年來 Uber 10-K 中描述的風險因素。以要點的形式給出答案。"
)
# 取得回答
response = agent.chat(cross_query_str)
# 輸出答案
print(str(response))
# Out:
# Added user message to memory: 哈囉，我是小柱子
# 哈囉小柱子，很高興見到你！有什麼我可以幫忙的嗎？
# Added user message to memory: 2020 年 Uber 面臨的最大風險因素有哪些？
# === Calling Function ===
# Calling function: vector_index_2020 with args: {"input":"What were the major risk factors faced by Uber in 2020?"}
# Got output: In 2020, Uber faced several major risk factors including:
#
# 1. **Data Privacy and Protection Risks**: Uber was concerned about potential investigations, inquiries, litigation, fines, and negative publicity related to its data handling practices.
#
# 2. **Intellectual Property Risks**: There was a risk of significant expenses and adverse effects on the business if Uber failed to protect its intellectual property or if it was accused of infringing on the intellectual property of others.
#
# 3. **Stock Volatility**: The market price of Uber’s common stock was subject to volatility and could decline regardless of the company's operating performance, potentially failing to meet investor or analyst expectations.
#
# 4. **Impact of COVID-19 Pandemic**: The pandemic adversely impacted Uber’s business, financial condition, and operations. Governmental restrictions and changes in consumer behavior reduced demand for mobility services, affected travel, and led to the suspension of services like UberPOOL.
#
# 5. **Operational Challenges Due to Remote Work**: The shift to widespread remote work could negatively impact operations, business plan execution, and the productivity of key personnel and service providers.
#
# 6. **Workforce Reductions**: Economic challenges prompted by the pandemic led Uber to announce significant workforce reductions, affecting about 6,700 full-time employee roles.
#
# 7. **Regulatory and Legal Challenges**: The rapid introduction of new services and expansion of existing ones in response to COVID-19 heightened the risk of legal and regulatory challenges, particularly as regulatory guidance continued to evolve.
#
# These factors collectively posed significant challenges to Uber’s operational stability and financial performance during the year 2020.
# ========================
#
# 在 2020 年，Uber 面臨了幾個主要的風險因素，包括：
#
# 1. **數據隱私和保護風險**：Uber 擔心可能會因其數據處理實踐而面臨調查、詢問、訴訟、罰款和負面公關。
#
# 2. **知識產權風險**：如果 Uber 未能保護其知識產權或被指控侵犯他人的知識產權，可能會導致重大支出和對業務的不利影響。
#
# 3. **股票波動性**：Uber 的普通股市價受到波動，可能會無視公司的營運表現而下跌，未能滿足投資者或分析師的期望。
#
# 4. **COVID-19 大流行的影響**：大流行對 Uber 的業務、財務狀況和運營產生了不利影響。政府限制和消費者行為的變化降低了對移動服務的需求，影響了旅行，並導致如 UberPOOL 之類的服務暫停。
#
# 5. **遠程工作帶來的運營挑戰**：廣泛的遠程工作轉變可能會對運營、業務計劃執行和關鍵人員及服務提供商的生產力產生負面影響。
#
# 6. **勞動力削減**：由於大流行帶來的經濟挑戰，Uber 宣布了大規模的勞動力削減，影響了約 6,700 個全職員工職位。
#
# 7. **監管和法律挑战**：為了應對 COVID-19，迅速引入新服務和擴展現有服務，增加了法律和監管挑戰的風險，特別是隨著監管指導的不斷演變。
#
# 這些因素在 2020 年共同對 Uber 的運營穩定性和財務表現構成了重大挑戰。
# Added user message to memory: 比較/對比多年來 Uber 10-K 中描述的風險因素。以要點的形式給出答案。
# === Calling Function ===
# Calling function: vector_index_2019 with args: {"input": "What were the major risk factors faced by Uber in 2019?"}
# Got output: In 2019, Uber faced several major risk factors including:
#
# 1. **Safety Incidents and Liability**: Uber was exposed to risks related to traffic accidents, deaths, injuries, or other incidents involving drivers, consumers, or third parties using its platform. These incidents could lead to significant liability and negative publicity, increasing operating costs and adversely affecting the business.
#
# 2. **Insurance Coverage Limitations**: The company's auto liability and general liability insurance policies might not cover all potential claims, nor be adequate to indemnify Uber for all liability, especially as the company expanded into new products like Freight, dockless e-bikes, and e-scooters.
#
# 3. **Data Security Breaches**: Uber could face significant liabilities and brand damage from data security breaches, such as the one experienced by Careem in January 2018. The company's overall security capabilities were also assessed as below or at the minimum maturity end of the industry range, indicating potential vulnerabilities.
#
# 4. **Investments in New Technologies and Offerings**: Substantial investments in new technologies and offerings, such as autonomous vehicles, dockless e-bikes, e-scooters, and Uber Elevate, were inherently risky. There was no guarantee that these investments would yield the expected benefits, adding financial risk.
#
# 5. **Regulatory and Legal Challenges**: Uber needed to navigate complex regulatory environments and could face liabilities from breaches experienced by acquired companies. Additionally, the company had to adapt to legal changes, such as those in California, which required modifications to its platform to protect driver independence and flexibility.
#
# These factors collectively posed significant challenges to Uber’s operational stability and financial growth in 2019.
# ========================
#
# === Calling Function ===
# Calling function: vector_index_2020 with args: {"input": "What were the major risk factors faced by Uber in 2020?"}
# Got output: In 2020, Uber faced several major risk factors including:
#
# 1. **Data Management Risks**: There were concerns about the collection, use, transfer, disclosure, and other processing of data which could lead to investigations, inquiries, litigation, fines, and negative publicity regarding privacy and data protection practices.
#
# 2. **Intellectual Property Risks**: There was a risk related to protecting Uber's intellectual property and potential claims of misappropriation by third parties, which could result in significant expenses and adversely affect the business.
#
# 3. **Stock Volatility**: The market price of Uber's common stock was subject to volatility and could decline steeply or suddenly regardless of the company's operating performance, potentially leading to losses for investors.
#
# 4. **Impact of COVID-19 Pandemic**: The pandemic adversely impacted Uber’s business, financial condition, and operations. Governmental restrictions like shelter-in-place orders, travel limitations, and social distancing measures reduced the demand for mobility offerings and affected travel behavior globally. Additionally, emergency orders in certain U.S. jurisdictions required capping fees charged to merchants on delivery services, and the suspension of UberPOOL also affected operations.
#
# 5. **Operational Challenges Due to Remote Work**: The shift to widespread remote work arrangements could negatively impact operations, execution of business plans, productivity, and availability of key personnel and third-party service providers. Increased remote working also raised concerns about privacy, cybersecurity, and fraud risks.
#
# 6. **Workforce Reductions**: In response to economic challenges from the pandemic, Uber announced significant workforce reductions, cutting approximately 6,700 full-time employee roles.
#
# 7. **Regulatory and Legal Challenges**: The rapid introduction of new services and expansion of existing ones in response to COVID-19, along with evolving health and safety requirements, could face legal or regulatory challenges. This includes potential fines or other enforcement measures that could adversely impact financial results or operations.
#
# These factors collectively posed significant challenges to Uber’s business continuity and growth during the year 2020.
# ========================
#
# === Calling Function ===
# Calling function: vector_index_2021 with args: {"input": "What were the major risk factors faced by Uber in 2021?"}
# Got output: In 2021, Uber faced several major risk factors that could adversely affect its business. These included the ongoing impact of the COVID-19 pandemic, the potential reclassification of drivers as employees rather than independent contractors, and intense competition in the mobility, delivery, and logistics industries. Additionally, Uber's need to maintain and enhance its brand and reputation, particularly in light of past negative publicity and operational challenges, was critical. The company also highlighted risks related to maintaining a critical mass of platform users, managing growth effectively, and dealing with safety incidents on its platform. Furthermore, substantial investments in new technologies and offerings, which are inherently risky, and the potential liabilities from data breaches, such as the one experienced by Careem, were significant concerns. Lastly, the introduction of new or upgraded products and features, which is costly and may not meet market acceptance, posed a risk to retaining and attracting users to its platform.
# ========================
#
# === Calling Function ===
# Calling function: vector_index_2022 with args: {"input": "What were the major risk factors faced by Uber in 2022?"}
# Got output: In 2022, Uber faced several major risk factors including:
#
# 1. **Cybersecurity Threats**: The company was at risk from software bugs, technical malfunctions, and cyberattacks such as malware, ransomware, and phishing. These could damage the company's reputation, disrupt business operations, and lead to significant financial losses.
#
# 2. **Failure to Innovate**: Uber's ability to attract and retain users depended heavily on its success in introducing new or upgraded products and features. Failure to do so could result in a loss of users to competitors.
#
# 3. **Brand and Reputation Management**: Maintaining and enhancing its brand and reputation was crucial. Negative publicity and historical workplace culture issues posed risks to the company's brand image.
#
# 4. **Regulatory and Legal Challenges**: The company faced risks related to regulatory changes and legal challenges that could affect its operations and financial performance.
#
# 5. **Operational and Financial Risks**: Uber had incurred significant losses and expected increased operating expenses. The company's financial health was a concern, especially if it failed to achieve or maintain profitability.
#
# 6. **Safety Concerns**: Incidents involving criminal, violent, or dangerous activities on its platform could harm Uber's ability to attract and retain users.
#
# 7. **Dependence on Specific Markets**: A significant portion of Uber's bookings came from large metropolitan areas, making it vulnerable to localized economic, social, and regulatory changes.
#
# 8. **Competition in Autonomous Vehicles**: There was a risk that Uber might fail to develop autonomous vehicle technologies effectively or before its competitors, which could impact its competitive edge.
#
# These factors collectively posed significant challenges to Uber's operational stability and growth prospects in 2022.
# ========================
#
# 在多年來，Uber 在其 10-K 文件中描述的風險因素有所變化和持續，以下是各年度的主要風險因素的比較和對比：
#
# ### 2019年
# 1. **安全事故和責任**：交通事故、死亡、傷害或其他涉及平台使用者的事件可能導致重大責任和負面公關。
# 2. **保險覆蓋限制**：保險可能不足以覆蓋所有潛在索賠。
# 3. **數據安全漏洞**：數據安全漏洞可能導致重大責任和品牌損害。
# 4. **新技術和產品投資**：如自動駕駛車輛和其他新產品的投資具有高風險。
# 5. **監管和法律挑戰**：需要應對複雜的監管環境和法律變更。
#
# ### 2020年
# 1. **數據管理風險**：數據收集和處理可能導致調查和訴訟。
# 2. **知識產權風險**：保護知識產權和應對第三方侵權指控。
# 3. **股票波動性**：股價可能會急劇波動。
# 4. **COVID-19大流行的影響**：對業務和運營造成重大影響。
# 5. **遠程工作帶來的運營挑戰**：可能影響業務計劃的執行和生產力。
# 6. **勞動力削減**：經濟挑戰導致大規模裁員。
# 7. **監管和法律挑戰**：新服務快速推出和擴展帶來的挑戰。
#
# ### 2021年
# 1. **COVID-19持續影響**：疫情持續對業務造成影響。
# 2. **司機身份重新分類的潛在風險**：司機可能被重新分類為員工而非獨立承包商。
# 3. **激烈的市場競爭**：在移動性、遞送和物流行業面臨激烈競爭。
# 4. **品牌和聲譽管理**：維護和提升品牌及聲譽至關重要。
# 5. **新技術和產品投資風險**：投資新技術和產品具有固有風險。
#
# ### 2022年
# 1. **網絡安全威脅**：軟件錯誤和網絡攻擊可能導致業務中斷和財務損失。
# 2. **創新失敗**：未能推出新產品或功能可能導致用戶流失。
# 3. **品牌和聲譽管理**：維護品牌形象面臨挑戰。
# 4. **監管和法律風險**：面臨可能影響運營和財務表現的監管和法律挑戰。
# 5. **運營和財務風險**：公司虧損持續，運營費用增加。
# 6. **安全顧慮**：平台上的犯罪或危險活動可能影響用戶信任。
# 7. **對特定市場的依賴**：業務高度依賴大都市區域。
# 8. **自動駕駛車輛的競爭**：開發自動駕駛技術的競爭風險。
#
# 這些風險因素顯示了 Uber 在不同年份面臨的挑战和焦點的變化，從安全和保險風險到技術創新和疫情影響，再到網絡安全和監管挑戰。

# %%
agent = OpenAIAgent.from_tools(tools)

while True:
    text_input = input("User: ")
    if text_input == "exit":
        break
    response = agent.chat(text_input)
    print(f"Agent: {response}")

# User: What were some of the legal proceedings against Uber in 2022?
# User: 2022 年針對 Uber 的一些法律訴訟有哪些
# Agent: (回應例子)
# Out:
# Agent: 2022年Uber的主要利潤來源是大都會區和機場往返的行程，這些行程佔總預訂額的一大部分。
